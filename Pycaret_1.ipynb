# %%
#!pip install pycaret

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer

# %%
# data = load_breast_cancer()
# x = data.data
# y = data.target

# %%
from pycaret.classification import setup,compare_models,save_model,evaluate_model,predict_model,create_model

# %%
df = pd.read_csv('train.csv')

# %%
s = setup(df,target='Survived')
# Out:
# <style type="text/css">
# #T_5819e_row5_col1, #T_5819e_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5819e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5819e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5819e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5819e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5819e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_5819e_row0_col1" class="data row0 col1" >1472</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5819e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5819e_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5819e_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_5819e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5819e_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_5819e_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5819e_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_5819e_row4_col1" class="data row4 col1" >(891, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5819e_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_5819e_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5819e_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_5819e_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5819e_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_5819e_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5819e_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_5819e_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5819e_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_5819e_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5819e_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_5819e_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5819e_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_5819e_row11_col1" class="data row11 col1" >(623, 708)</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5819e_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_5819e_row12_col1" class="data row12 col1" >(268, 708)</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5819e_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_5819e_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5819e_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_5819e_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5819e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_5819e_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5819e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_5819e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5819e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_5819e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5819e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_5819e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5819e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_5819e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5819e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_5819e_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5819e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_5819e_row21_col1" class="data row21 col1" >0601</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5819e_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_5819e_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_5819e_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_5819e_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_5819e_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_5819e_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_5819e_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_5819e_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_5819e_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_5819e_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_5819e_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_5819e_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_5819e_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_5819e_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_5819e_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_5819e_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5819e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_5819e_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_5819

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_6571b th {
#   text-align: left;
# }
# #T_6571b_row0_col0, #T_6571b_row0_col2, #T_6571b_row0_col3, #T_6571b_row0_col4, #T_6571b_row0_col5, #T_6571b_row0_col6, #T_6571b_row1_col0, #T_6571b_row1_col1, #T_6571b_row1_col2, #T_6571b_row1_col3, #T_6571b_row1_col4, #T_6571b_row1_col7, #T_6571b_row2_col0, #T_6571b_row2_col1, #T_6571b_row2_col2, #T_6571b_row2_col3, #T_6571b_row2_col4, #T_6571b_row2_col5, #T_6571b_row2_col6, #T_6571b_row2_col7, #T_6571b_row3_col0, #T_6571b_row3_col1, #T_6571b_row3_col3, #T_6571b_row3_col5, #T_6571b_row3_col6, #T_6571b_row3_col7, #T_6571b_row4_col0, #T_6571b_row4_col1, #T_6571b_row4_col2, #T_6571b_row4_col3, #T_6571b_row4_col4, #T_6571b_row4_col5, #T_6571b_row4_col6, #T_6571b_row4_col7, #T_6571b_row5_col0, #T_6571b_row5_col1, #T_6571b_row5_col2, #T_6571b_row5_col3, #T_6571b_row5_col4, #T_6571b_row5_col5, #T_6571b_row5_col6, #T_6571b_row5_col7, #T_6571b_row6_col0, #T_6571b_row6_col1, #T_6571b_row6_col2, #T_6571b_row6_col3, #T_6571b_row6_col4, #T_6571b_row6_col5, #T_6571b_row6_col6, #T_6571b_row6_col7, #T_6571b_row7_col0, #T_6571b_row7_col1, #T_6571b_row7_col2, #T_6571b_row7_col3, #T_6571b_row7_col4, #T_6571b_row7_col5, #T_6571b_row7_col6, #T_6571b_row7_col7, #T_6571b_row8_col0, #T_6571b_row8_col1, #T_6571b_row8_col2, #T_6571b_row8_col3, #T_6571b_row8_col4, #T_6571b_row8_col5, #T_6571b_row8_col6, #T_6571b_row8_col7, #T_6571b_row9_col0, #T_6571b_row9_col1, #T_6571b_row9_col2, #T_6571b_row9_col3, #T_6571b_row9_col4, #T_6571b_row9_col5, #T_6571b_row9_col6, #T_6571b_row9_col7, #T_6
row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_6571b_row2_col3" class="data row2 col3" >0.6996</td>
#       <td id="T_6571b_row2_col4" class="data row2 col4" >0.7681</td>
#       <td id="T_6571b_row2_col5" class="data row2 col5" >0.7291</td>
#       <td id="T_6571b_row2_col6" class="data row2 col6" >0.5789</td>
#       <td id="T_6571b_row2_col7" class="data row2 col7" >0.5832</td>
#       <td id="T_6571b_row2_col8" class="data row2 col8" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_6571b_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_6571b_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6571b_row3_col1" class="data row3 col1" >0.8057</td>
#       <td id="T_6571b_row3_col2" class="data row3 col2" >0.8572</td>
#       <td id="T_6571b_row3_col3" class="data row3 col3" >0.6060</td>
#       <td id="T_6571b_row3_col4" class="data row3 col4" >0.8383</td>
#       <td id="T_6571b_row3_col5" class="data row3 col5" >0.7011</td>
#       <td id="T_6571b_row3_col6" class="data row3 col6" >0.5632</td>
#       <td id="T_6571b_row3_col7" class="data row3 col7" >0.5811</td>
#       <td id="T_6571b_row3_col8" class="data row3 col8" >0.5640</td>
#     </tr>
#     <tr>
#       <th id="T_6571b_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_6571b_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6571b_row4_col1" class="data row4 col1" >0.8041</td>
#       <td id="T_6571b_row4_col2" class="data row4 col2" >0.8464</td>
#       <td id="T_6571b_row4_col3" class="data row4 col3" >0.6913</td>
#       <td id="T_6571b_row4_col4" class="data row4 col4" >0.7766</td>
#       <td id="T_6571b_row4_col5" class="data row4 col5" >0.7289</td>
#       <td id="T_6571b_row4_col6" class="data row4 col6" >0.5765</td>
#       <td id="T_6571b_row4_col7" class="data row4 col7" >0.5814</td>
#       <td id="T_6571b_row4_col8" class="data row4 col8" >0.1770</td>
#     </tr>
#     <tr>
#       <th id="T_6571b_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_6571b_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_6571b_row5_col1" class="data row5 col1" >0.7994</td>
#       <td id="T_6571b_row5_col2" class="data

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
# Error in callback <function flush_figures at 0x0000029BA500DCA0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#    1895             if self.arrow_patch.figure is None and self.figure is not None:
#    1896                 self.arrow_patch.figure = self.figure
# -> 1897             self.arrow_patch.draw(renderer)
#    1898         # Draw text, including FancyBboxPatch, after FancyArrowPatch.
#    1899         # Otherwise, a wedge arrowstyle can land partly on top of the Bbox.
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\patches.py in draw(self, renderer)
#    4168             # could be room for improvement.
#    4169             self.set_dpi_cor(renderer.points_to_pixels(1.))
# -> 4170             path, fillable = self.get_path_in_displaycoord()
#    4171
#    4172             if not np.iterable(fillable):
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\patches.py in get_path_in_displaycoord(self)
#    4139             posB = self._convert_xy_units(self._posA_posB[1])
#    4140             (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4141             _path = self.get_connectionstyle()(posA, posB,
#    4142                                                patchA=self.patchA,
#    4143                                                patchB=self.patchB,
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2490             """
#    2491             path = self.connect(posA, posB)
# -> 2492             clipped_path = self._clip(path, patchA, patchB)
#    2493             shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2494             return shrunk_path
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\patches.py in _clip(self, path, patchA, patchB)
#    2445
#    2446                 try:
# -> 2447                     left, right = split_path_inout(path, insideA)
#    2448                 except ValueError:
#    2449                     right = path
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     367
#     368     bp = bezier_path.reshape((-1, 2))
# --> 369     left, right = split_bezier_intersecting_with_closedpath(
#     370         bp, inside, tolerance)
#     371     if len(left) == 2:
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     330     bezier_point_at_t = bz.point_at_t
#     331
# --> 332     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     333         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     334
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     168         middle_t = 0.5 * (t0 + t1)
#     169         middle = bezier_point_at_t(middle_t)
# --> 170         middle_inside = inside_closedpath(middle)
#     171
#     172         if start_inside ^ middle_inside:
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\patches.py in insideA(xy_display)
#    2442                 def insideA(xy_display):
#    2443                     xy_event = ConnectionStyle._Base.SimpleEvent(xy_display)
# -> 2444                     return patchA.contains(xy_event)[0]
#    2445
#    2446                 try:
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\patches.py in contains(self, mouseevent, radius)
#     145         else:
#     146             subpaths = [self.get_path()]
# --> 147         inside = any(
#     148             subpath.contains_point(
#     149                 (mouseevent.x, mouseevent.y), self.get_transform(), radius)
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\patches.py in <genexpr>(.0)
#     146             subpaths = [self.get_path()]
#     147         inside = any(
# --> 148             subpath.contains_point(
#     149                 (mouseevent.x, mouseevent.y), self.get_transform(), radius)
#     150             for subpath in subpaths)
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\path.py in contains_point(self, point, transform, radius)
#     520         """
#     521         if transform is not None:
# --> 522             transform = transform.frozen()
#     523         # `point_in_path` does not handle nonlinear transforms, so we
#     524         # transform the path ourselves.  If *transform* is affine, letting
#
# c:\users\mujtaba\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    1765     def frozen(self):
#    1766         # docstring inherited
# -> 1767         return Affine2D(self.get_matrix().copy())
#    1768
#    1769     @property
#
# KeyboardInterrupt:

# %%
test = pd.read_csv('test.csv')
# rf = create_model(test)
#rf.predict(test.csv)

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
predict_model(best_model,test)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#      Label  Score
# 0        0   0.85
# 1        0   0.50
# 2        0   0.84
# 3        0   0.89
# 4        0   0.54
# ..     ...    ...
# 413      0   0.94
# 414      1   0.99
# 415      0   0.93
# 416      0   0.94
# 417      0   0.57
#
# [418 rows x 13 columns]

# %%
save_model(best_model,'rf')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['PassengerId'],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Survived',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=Non...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='auto',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=100, n_jobs=-1,
#                                          oob_score=False, random_state=1472,
#                                          verbose=0, warm_start=False)]],
#           verbose=False),
#  'rf.pkl')
